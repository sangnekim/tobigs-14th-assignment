# %% [markdown]
# # 네이버 자주 본 뉴스 크롤링
#
# 1) 수집내용
#
#     1) 많이본뉴스–섹션별(정치~IT/과학)Top5기사제목,신문사,뷰
#     2) 해당 기사별 기사 내용, 리액션 (좋아요 ~ 후속기사 원해요)
#
# 2) 수집방법(택1)
#
#     1) [기본] Requests , BeautifulSoup, Selenium
#     2) [심화] Requests, BeautifulSoup (+ 멀티프로세싱)
#
# 3) 수집범위 및 저장
#
#     1) 2019년7월21일~2020년8월20일(동작가능,실제구동x)
#     2) 하나의 파일로 저장 (방식 자유)
#     3) Ex)총6섹션*Top5*365일=10950rows

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

from selenium import webdriver
from IPython.display import Image
import os
from pathlib import Path
import glob

import datetime

# %% [markdown]
# ## 날짜 String 생성

# %%
start_date = datetime.datetime(2019, 7, 21, 3, 22, 32)
# start_date.strftime("%Y%m%d %Y-%m-%d 시간 표시외 %H:%M:%S 아무거나 넣어도 됩니다.") #strftime 활용 예시

# %%
def get_date_string(start_date, period=365):
    # 20190721 형태의 Date String List 생성
    return [
        (start_date + datetime.timedelta(days=day)).strftime("%Y%m%d")
        for day in range(period)
    ]

# %%
date_string_list = get_date_string(start_date, 366)

# %%
date_string_list[0], date_string_list[-1] # 생성 완료
# Out:
# ('20190721', '20200720')

# %% [markdown]
# ## Part 1. Request를 이용한 크롤링

# %%
def get_top_news(date):
    """
    해당 날짜의 자주 본 뉴스 25개에 대한 정보를 반환하는 함수입니다.
    """
    url = f"https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&date={date}" # 이부분을 잘 채워넣어주세요 (네이버 뉴스 자주보는 뉴스 링크에서 date를 제외한 부분)
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    
    result = []
    
    count = 0
    title_link = soup.select("li > dl > dt > a")
    publisher_main = soup.select("li > dl > dd > span:nth-child(2n)")
    publisher = soup.select("li > dl > dt > span:nth-child(2n)")
    view_main = soup.select("li > dl > dd> i.count_view")
    view = soup.select("li > dl > dt> i.count_view")
    while title_link:
        temp = title_link.pop(0)
        title = temp.text
        link = temp["href"]
        if count%5 == 0:
            temp = publisher_main.pop(0)
            publish = temp.text.strip()
            temp = view_main.pop(0)
            views = temp.text
        else:
            temp = publisher.pop(0)
            publish = temp.text.strip()
            temp = view.pop(0)
            views = temp.text
        temp_list = [title,link,publish,views]
        result.append(temp_list)
        count +=1
    # soup.select를 잘 활용하여
    # 1. 신문 제목
    # 2. 기사 링크 (a tag의 href 속성) 
    # 3. 신문사명
    # 4. View
    
    return result

# %%
# 1년치 전체를 하는 것이 아닌 앞 20일치만 테스트 해보기 위함 (개인적으로 바꿔도 무방)
news_data = []
for date in date_string_list:
     news_data.extend(get_top_news(date)) # 결과로 나온 25개를 이어 붙임

# %%
len(news_data)
# Out:
# 600

# %%
news_data[:5] # 결과 예시
# Out:
# [['[단독] 황교안 딸 운영 사이트, 대학 진학 후 왜 문 닫았나',
#   '/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=032&aid=0002952683&date=20190721&type=1&rankingSectionId=100&rankingSeq=1',
#   '경향신문',
#   '201,039'],
#  ['조국 폭풍페북, 日주장 정면반박…"친일파" 표현은 野 반발',
#   '/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004251344&date=20190721&type=1&rankingSectionId=100&rankingSeq=2',
#   '머니투데이',
#   '185,396'],
#  ['조국, 연일 對日 \'항전\' 주문…"겁먹고 쫄지말자…싸워 이겨…',
#   '/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0010969325&date=20190721&type=1&rankingSectionId=100&rankingSeq=3',
#   '연합뉴스',
#   '130,198'],
#  ['[김순덕의 도발]복수를 하려면 아일랜드처럼!',
#   '/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=020&aid=0003230442&date=20190721&type=1&rankingSectionId=100&rankingSeq=4',
#   '동아일보',
#   '120,897'],
#  ['조국, 또 페북에 反日 선전전..."文정부, 서희·이순신 역할…',
#   '/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003462170&date=20190721&type=1&rankingSectionId=100&rankingSeq=5',
#   '조선일보',
#   '119,463']]

# %%
# 결과물을 데이터 프레임으로 변환 및 Column Name 부여
df_top_news = pd.DataFrame(news_data, columns=["title", "url", "press", "views"])

# %%
df_top_news
# Out:
#                                       title  \
# 0        [단독] 황교안 딸 운영 사이트, 대학 진학 후 왜 문 닫았나
# 1          조국 폭풍페북, 日주장 정면반박…"친일파" 표현은 野 반발
# 2        조국, 연일 對日 '항전' 주문…"겁먹고 쫄지말자…싸워 이겨…
# 3                  [김순덕의 도발]복수를 하려면 아일랜드처럼!
# 4       조국, 또 페북에 反日 선전전..."文정부, 서희·이순신 역할…
# 5          [취재파일] 日 경제 보복…이재용의 침묵과 최태원의 당당함
# 6               불매운동에 놀란 유니클로 대표 "추가 사과할 것"
# 7           일본 여행 갔다고 '공개 망신'…"성숙한 불매운동 필요"
# 8             "예·적금 가입 서두르세요"···2%대 이자 사라진다
# 9        '주식투자로 50평 아파트' 70대 노부인의 행동재무학 재테크
# 10      [인턴액티브] "보기 불편" vs "왜 여성만"…'노브라' 논란
# 11        “맞는 날 보고도 구경한 경찰…간부가 찾아와 영상 내리라고…
# 12     '그것이 알고싶다' 11년째 지명수배 1번 황주연 "나는 안 잡…
# 13      영화 ‘도둑들’ 출연 홍콩 배우 런다화, 중국 행사 중 흉기 …
# 14         마동석, 마블영화로 할리우드 진출···'이터널스'의 길가…
# 15       설리 "과거 임신설, 병원 직원이 차트 유출해 상처받아" 울…
# 16       '車 사이드미러 없어진다'..현대모비스, 카메라모니터 기술 …
# 17     32억원 받게 될 로또 868회 ‘1등’ 당첨번호는…당첨자 6명
# 18      [30대에 알았다면 좋았을 것들] "선배 때문에 힘들었어요" …
# 19           ‘사이드미러가 사라진다’…모비스, 카메라 모니터 개발
# 20           홍콩 유명배우 런다화 중국서 행사도중 칼에 찔려(종합)
# 21          이 함성 실화? “아베 물러나라!” 일본 도심 울린 외침
# 22      영화 ‘도둑들’ 나온 홍콩 배우 런다화, 中행사 도중 흉기에 …
# 23                선거 이긴 아베 "韓, 제대로된 답변 내놔야"
# 24         NHK 출구조사 결과 “日 여당, 참의원선거서 과반 확보”
# 25        日 횡포에 애플·아마존도 '패닉'…"반도체 공급차질 거듭 …
# 26        "고가폰 왜사요?"…'가성비' 저격 중저가 삼성폰 '탐나네'
# 27        국내 ‘여성용 비아그라’ 신약 도입되나··광동제약 발매 추…
# 28               안 터지는 5G…'전국망 구축' 내년에도 어렵다
# 29        '인기' 떨어진 아이폰 고객 '엑소더스'…삼성·LG 힘받는다
# ..                                      ...
# 570    나경원, 악플러 170명 고소… 누리꾼 "나베가 그런 뜻인 줄 …
# 571        한밤의 대남 경고장 날린 北 "고단할 정도 대가 치를 것"
# 572        하버드졸업 후 육아중이었는데…20대국회 막차 36살 정은혜
# 573         황교안·나경원·유기준 '언중유골'에 몸 바짝 낮춘 윤석열
# 574      문준용, "文씨 사업 문제 있나 확인해보겠다"는 곽상도에 "…
# 575                 이마트 창사 첫 적자…대형마트 '수난시대'
# 576    韓, 반도체 D램 점유율 75% 압도적…"日보복 영향 안 클 듯"
# 577       ‘문재인 면상 주먹으로’ 한국콜마 황당 해명…“올바른 역사…
# 578      [먼저 써봤습니다] 전문용어 1도 없는 쉬운 갤노트10 안내서
# 579       “여자 덕에 먹고사는 회사가…” 한국콜마에 등 돌린 소비자…
# 580     '보복운전' 최민수에 징역 1년 구형…"욕설한 것 후회 안 해…
# 581    [종합]'BJ 서윤과 열애' 우창범, '철구와 원정도박 동행' …
# 582    "한국 여성들 곧 싼 값에 몸 팔 것" '한국콜마' 윤동한 회장…
# 583     한국콜마 회장, ‘韓여성들 곧 싼값에 몸팔 것’ 내용 영상 직…
# 584      "마닐라 카지노 사진, 철구 맞다…휴가 복귀 즉시 조사할 것…
# 585           태풍 북상에 중국·일본 '긴장'…한국 상대적 '여유'
# 586     92세 송해 "난 일제강점기 겪어···日, 그 핍박 갚을 수 …
# 587       아픈 아들을 간호하던 의사아버지, 북적거리는 6인용 병실에…
# 588        유명세 ‘상근이’들은 왜 유기견이 되었나…수요·공급의 비…
# 589               인도서 남들이 후진할 때… 현대차는 가속합니다
# 590               일본, 야스쿠니 폭발물 설치 한국인 이송 불허
# 591          무역전쟁 반격 카드 꺼내든 중국…'희토류 무기화' 선언
# 592      아베 코앞에서 'NO 아베' 외친 日 시민들..."분노한다!"
# 593     [글로벌 돋보기] “도쿄 ‘방사능’ 올림픽 우려”…세계 각국 …
# 594        "예상 이상으로 소동 커졌다"…日, 수출규제 반응 '당혹'
# 595        갤노트10 만져본 미국인들 "실물 보고싶어 일부러 찾아와"
# 596  "유튜브 뛰어드니"…월급 295만→536만원 '껑충' vs 소득 '…
# 597    [SNS 세상] "공감이 최고의 위로" 암 투병기 연재하는 뷰티…
# 598      네이버·카카오 2분기 성적표 '희비'…하반기 '페이전쟁' 격…
# 599                 삼성전자 사장, 처음으로 '위기'를 말하다
#
#                                                    url   press    views
# 0    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    경향신문  201,039
# 1    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...   머니투데이  185,396
# 2    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    연합뉴스  130,198
# 3    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    동아일보  120,897
# 4    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    조선일보  119,463
# 5    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     SBS  157,764
# 6    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...   머니투데이  136,808
# 7    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     SBS  126,836
# 8    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    서울경제  125,516
# 9    /main/ranking/read.nhn?mid=etc&sid1=111&rankin...   머니투데이  122,556
# 10   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    연합뉴스  268,994
# 11   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    국민일보  201,161
# 12   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...   아시아경제  182,382
# 13   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  163,451
# 14   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    경향신문  156,890
# 15   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  138,762
# 16   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...  파이낸셜뉴스   98,156
# 17   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    국민일보   89,931
# 18   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...   오마이뉴스   86,941
# 19   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     한겨레   78,265
# 20   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    연합뉴스  198,246
# 21   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    국민일보  163,026
# 22   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    국민일보  134,679
# 23   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    매일경제  133,231
# 24   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  123,756
# 25   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...  한국경제TV  122,285
# 26   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     뉴스1  106,308
# 27   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    서울경제   71,652
# 28   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    한국경제   66,678
# 29   /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     뉴스1   46,854
# ..                                                 ...     ...      ...
# 570  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    세계일보  148,109
# 571  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  130,436
# 572  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     뉴스1  125,501
# 573  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    데일리안  105,695
# 574  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    조선일보  104,774
# 575  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    한국경제  254,816
# 576  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  173,250
# 577  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     한겨레  166,952
# 578  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  132,321
# 579  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    국민일보  124,227
# 580  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    연합뉴스  466,116
# 581  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    서울경제  310,495
# 582  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...   아시아경제  282,569
# 583  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    국민일보  201,686
# 584  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...  아이뉴스24  167,978
# 585  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    연합뉴스  201,386
# 586  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    중앙일보  172,678
# 587  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    동아일보   93,452
# 588  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     한겨레   84,471
# 589  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    조선일보   80,202
# 590  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    서울신문  158,233
# 591  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    JTBC  145,170
# 592  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     YTN  143,064
# 593  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     KBS  136,602
# 594  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     뉴스1  126,252
# 595  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    서울경제  173,703
# 596  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     뉴스1  134,014
# 597  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    연합뉴스  111,786
# 598  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...     뉴스1   77,278
# 599  /main/ranking/read.nhn?mid=etc&sid1=111&rankin...    조선일보   68,369
#
# [600 rows x 4 columns]

# %%
# URL 앞에  "https://news.naver.com" 붙이기
df_top_news.url = "https://news.naver.com"+df_top_news.url # 여기를 채워넣어주세요

# %%
df_top_news
# Out:
#                                       title  \
# 0        [단독] 황교안 딸 운영 사이트, 대학 진학 후 왜 문 닫았나
# 1          조국 폭풍페북, 日주장 정면반박…"친일파" 표현은 野 반발
# 2        조국, 연일 對日 '항전' 주문…"겁먹고 쫄지말자…싸워 이겨…
# 3                  [김순덕의 도발]복수를 하려면 아일랜드처럼!
# 4       조국, 또 페북에 反日 선전전..."文정부, 서희·이순신 역할…
# 5          [취재파일] 日 경제 보복…이재용의 침묵과 최태원의 당당함
# 6               불매운동에 놀란 유니클로 대표 "추가 사과할 것"
# 7           일본 여행 갔다고 '공개 망신'…"성숙한 불매운동 필요"
# 8             "예·적금 가입 서두르세요"···2%대 이자 사라진다
# 9        '주식투자로 50평 아파트' 70대 노부인의 행동재무학 재테크
# 10      [인턴액티브] "보기 불편" vs "왜 여성만"…'노브라' 논란
# 11        “맞는 날 보고도 구경한 경찰…간부가 찾아와 영상 내리라고…
# 12     '그것이 알고싶다' 11년째 지명수배 1번 황주연 "나는 안 잡…
# 13      영화 ‘도둑들’ 출연 홍콩 배우 런다화, 중국 행사 중 흉기 …
# 14         마동석, 마블영화로 할리우드 진출···'이터널스'의 길가…
# 15       설리 "과거 임신설, 병원 직원이 차트 유출해 상처받아" 울…
# 16       '車 사이드미러 없어진다'..현대모비스, 카메라모니터 기술 …
# 17     32억원 받게 될 로또 868회 ‘1등’ 당첨번호는…당첨자 6명
# 18      [30대에 알았다면 좋았을 것들] "선배 때문에 힘들었어요" …
# 19           ‘사이드미러가 사라진다’…모비스, 카메라 모니터 개발
# 20           홍콩 유명배우 런다화 중국서 행사도중 칼에 찔려(종합)
# 21          이 함성 실화? “아베 물러나라!” 일본 도심 울린 외침
# 22      영화 ‘도둑들’ 나온 홍콩 배우 런다화, 中행사 도중 흉기에 …
# 23                선거 이긴 아베 "韓, 제대로된 답변 내놔야"
# 24         NHK 출구조사 결과 “日 여당, 참의원선거서 과반 확보”
# 25        日 횡포에 애플·아마존도 '패닉'…"반도체 공급차질 거듭 …
# 26        "고가폰 왜사요?"…'가성비' 저격 중저가 삼성폰 '탐나네'
# 27        국내 ‘여성용 비아그라’ 신약 도입되나··광동제약 발매 추…
# 28               안 터지는 5G…'전국망 구축' 내년에도 어렵다
# 29        '인기' 떨어진 아이폰 고객 '엑소더스'…삼성·LG 힘받는다
# ..                                      ...
# 570    나경원, 악플러 170명 고소… 누리꾼 "나베가 그런 뜻인 줄 …
# 571        한밤의 대남 경고장 날린 北 "고단할 정도 대가 치를 것"
# 572        하버드졸업 후 육아중이었는데…20대국회 막차 36살 정은혜
# 573         황교안·나경원·유기준 '언중유골'에 몸 바짝 낮춘 윤석열
# 574      문준용, "文씨 사업 문제 있나 확인해보겠다"는 곽상도에 "…
# 575                 이마트 창사 첫 적자…대형마트 '수난시대'
# 576    韓, 반도체 D램 점유율 75% 압도적…"日보복 영향 안 클 듯"
# 577       ‘문재인 면상 주먹으로’ 한국콜마 황당 해명…“올바른 역사…
# 578      [먼저 써봤습니다] 전문용어 1도 없는 쉬운 갤노트10 안내서
# 579       “여자 덕에 먹고사는 회사가…” 한국콜마에 등 돌린 소비자…
# 580     '보복운전' 최민수에 징역 1년 구형…"욕설한 것 후회 안 해…
# 581    [종합]'BJ 서윤과 열애' 우창범, '철구와 원정도박 동행' …
# 582    "한국 여성들 곧 싼 값에 몸 팔 것" '한국콜마' 윤동한 회장…
# 583     한국콜마 회장, ‘韓여성들 곧 싼값에 몸팔 것’ 내용 영상 직…
# 584      "마닐라 카지노 사진, 철구 맞다…휴가 복귀 즉시 조사할 것…
# 585           태풍 북상에 중국·일본 '긴장'…한국 상대적 '여유'
# 586     92세 송해 "난 일제강점기 겪어···日, 그 핍박 갚을 수 …
# 587       아픈 아들을 간호하던 의사아버지, 북적거리는 6인용 병실에…
# 588        유명세 ‘상근이’들은 왜 유기견이 되었나…수요·공급의 비…
# 589               인도서 남들이 후진할 때… 현대차는 가속합니다
# 590               일본, 야스쿠니 폭발물 설치 한국인 이송 불허
# 591          무역전쟁 반격 카드 꺼내든 중국…'희토류 무기화' 선언
# 592      아베 코앞에서 'NO 아베' 외친 日 시민들..."분노한다!"
# 593     [글로벌 돋보기] “도쿄 ‘방사능’ 올림픽 우려”…세계 각국 …
# 594        "예상 이상으로 소동 커졌다"…日, 수출규제 반응 '당혹'
# 595        갤노트10 만져본 미국인들 "실물 보고싶어 일부러 찾아와"
# 596  "유튜브 뛰어드니"…월급 295만→536만원 '껑충' vs 소득 '…
# 597    [SNS 세상] "공감이 최고의 위로" 암 투병기 연재하는 뷰티…
# 598      네이버·카카오 2분기 성적표 '희비'…하반기 '페이전쟁' 격…
# 599                 삼성전자 사장, 처음으로 '위기'를 말하다
#
#                                                    url   press    views
# 0    https://news.naver.com/main/ranking/read.nhn?m...    경향신문  201,039
# 1    https://news.naver.com/main/ranking/read.nhn?m...   머니투데이  185,396
# 2    https://news.naver.com/main/ranking/read.nhn?m...    연합뉴스  130,198
# 3    https://news.naver.com/main/ranking/read.nhn?m...    동아일보  120,897
# 4    https://news.naver.com/main/ranking/read.nhn?m...    조선일보  119,463
# 5    https://news.naver.com/main/ranking/read.nhn?m...     SBS  157,764
# 6    https://news.naver.com/main/ranking/read.nhn?m...   머니투데이  136,808
# 7    https://news.naver.com/main/ranking/read.nhn?m...     SBS  126,836
# 8    https://news.naver.com/main/ranking/read.nhn?m...    서울경제  125,516
# 9    https://news.naver.com/main/ranking/read.nhn?m...   머니투데이  122,556
# 10   https://news.naver.com/main/ranking/read.nhn?m...    연합뉴스  268,994
# 11   https://news.naver.com/main/ranking/read.nhn?m...    국민일보  201,161
# 12   https://news.naver.com/main/ranking/read.nhn?m...   아시아경제  182,382
# 13   https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  163,451
# 14   https://news.naver.com/main/ranking/read.nhn?m...    경향신문  156,890
# 15   https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  138,762
# 16   https://news.naver.com/main/ranking/read.nhn?m...  파이낸셜뉴스   98,156
# 17   https://news.naver.com/main/ranking/read.nhn?m...    국민일보   89,931
# 18   https://news.naver.com/main/ranking/read.nhn?m...   오마이뉴스   86,941
# 19   https://news.naver.com/main/ranking/read.nhn?m...     한겨레   78,265
# 20   https://news.naver.com/main/ranking/read.nhn?m...    연합뉴스  198,246
# 21   https://news.naver.com/main/ranking/read.nhn?m...    국민일보  163,026
# 22   https://news.naver.com/main/ranking/read.nhn?m...    국민일보  134,679
# 23   https://news.naver.com/main/ranking/read.nhn?m...    매일경제  133,231
# 24   https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  123,756
# 25   https://news.naver.com/main/ranking/read.nhn?m...  한국경제TV  122,285
# 26   https://news.naver.com/main/ranking/read.nhn?m...     뉴스1  106,308
# 27   https://news.naver.com/main/ranking/read.nhn?m...    서울경제   71,652
# 28   https://news.naver.com/main/ranking/read.nhn?m...    한국경제   66,678
# 29   https://news.naver.com/main/ranking/read.nhn?m...     뉴스1   46,854
# ..                                                 ...     ...      ...
# 570  https://news.naver.com/main/ranking/read.nhn?m...    세계일보  148,109
# 571  https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  130,436
# 572  https://news.naver.com/main/ranking/read.nhn?m...     뉴스1  125,501
# 573  https://news.naver.com/main/ranking/read.nhn?m...    데일리안  105,695
# 574  https://news.naver.com/main/ranking/read.nhn?m...    조선일보  104,774
# 575  https://news.naver.com/main/ranking/read.nhn?m...    한국경제  254,816
# 576  https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  173,250
# 577  https://news.naver.com/main/ranking/read.nhn?m...     한겨레  166,952
# 578  https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  132,321
# 579  https://news.naver.com/main/ranking/read.nhn?m...    국민일보  124,227
# 580  https://news.naver.com/main/ranking/read.nhn?m...    연합뉴스  466,116
# 581  https://news.naver.com/main/ranking/read.nhn?m...    서울경제  310,495
# 582  https://news.naver.com/main/ranking/read.nhn?m...   아시아경제  282,569
# 583  https://news.naver.com/main/ranking/read.nhn?m...    국민일보  201,686
# 584  https://news.naver.com/main/ranking/read.nhn?m...  아이뉴스24  167,978
# 585  https://news.naver.com/main/ranking/read.nhn?m...    연합뉴스  201,386
# 586  https://news.naver.com/main/ranking/read.nhn?m...    중앙일보  172,678
# 587  https://news.naver.com/main/ranking/read.nhn?m...    동아일보   93,452
# 588  https://news.naver.com/main/ranking/read.nhn?m...     한겨레   84,471
# 589  https://news.naver.com/main/ranking/read.nhn?m...    조선일보   80,202
# 590  https://news.naver.com/main/ranking/read.nhn?m...    서울신문  158,233
# 591  https://news.naver.com/main/ranking/read.nhn?m...    JTBC  145,170
# 592  https://news.naver.com/main/ranking/read.nhn?m...     YTN  143,064
# 593  https://news.naver.com/main/ranking/read.nhn?m...     KBS  136,602
# 594  https://news.naver.com/main/ranking/read.nhn?m...     뉴스1  126,252
# 595  https://news.naver.com/main/ranking/read.nhn?m...    서울경제  173,703
# 596  https://news.naver.com/main/ranking/read.nhn?m...     뉴스1  134,014
# 597  https://news.naver.com/main/ranking/read.nhn?m...    연합뉴스  111,786
# 598  https://news.naver.com/main/ranking/read.nhn?m...     뉴스1   77,278
# 599  https://news.naver.com/main/ranking/read.nhn?m...    조선일보   68,369
#
# [600 rows x 4 columns]

# %% [markdown]
# ## Part 2. Selenium을 이용한 크롤링

# %%
driver_path = os.path.join(Path().absolute(), "chromedriver")# driver 경로 설정

# %%
driver = webdriver.Chrome(driver_path) # Chrome driver 실행

# %%
df_top_news.url[:10]
# Out:
# 0    https://news.naver.com/main/ranking/read.nhn?m...
# 1    https://news.naver.com/main/ranking/read.nhn?m...
# 2    https://news.naver.com/main/ranking/read.nhn?m...
# 3    https://news.naver.com/main/ranking/read.nhn?m...
# 4    https://news.naver.com/main/ranking/read.nhn?m...
# 5    https://news.naver.com/main/ranking/read.nhn?m...
# 6    https://news.naver.com/main/ranking/read.nhn?m...
# 7    https://news.naver.com/main/ranking/read.nhn?m...
# 8    https://news.naver.com/main/ranking/read.nhn?m...
# 9    https://news.naver.com/main/ranking/read.nhn?m...
# Name: url, dtype: object

# %%
# NEWS_TEST_RANGE = 10
for idx, news_url in enumerate(df_top_news.url):
    # 드라이버 내에서 해당 URL로 이동
    driver.get(news_url)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    
    ## BeautifulSoup 혹은 driver.find_element[s]_by_css_selector 을 이용하여 정보 파싱
    # +기사 내용
    content = soup.select("#articleBodyContents")[0].get_text().replace('\n', " ") 

    # +5가지 리액션 (좋아요, 훈훈해요, 슬퍼요, 화나요, 후속기사원해요) 투표 수
    key_list = ['좋아요', '훈훈해요', '슬퍼요', '화나요', '후속기사원해요']
    value_list = []
    for i in range(5):
        temp = driver.find_elements_by_css_selector("#spiLayer > div._reactionModule.u_likeit > ul > li")[i].text
        value_list.append(''.join(list(filter(str.isdigit,temp))))
    reaction_dict = {k:v for k,v in zip(key_list, value_list)}
    
    
    
    # 예시로 content라는 변수에 기사 내용을 담고 Column "content"에 해당 내용 저장
    df_top_news.loc[idx,"content"] = content
    for k,v in reaction_dict.items():
        df_top_news.loc[idx,k] = v
driver.close()

# %%
df_top_news.head(5)
# Out:
#                                  title  \
# 0   [단독] 황교안 딸 운영 사이트, 대학 진학 후 왜 문 닫았나
# 1     조국 폭풍페북, 日주장 정면반박…"친일파" 표현은 野 반발
# 2   조국, 연일 對日 '항전' 주문…"겁먹고 쫄지말자…싸워 이겨…
# 3             [김순덕의 도발]복수를 하려면 아일랜드처럼!
# 4  조국, 또 페북에 反日 선전전..."文정부, 서희·이순신 역할…
#
#                                                  url  press    views  \
# 0  https://news.naver.com/main/ranking/read.nhn?m...   경향신문  201,039
# 1  https://news.naver.com/main/ranking/read.nhn?m...  머니투데이  185,396
# 2  https://news.naver.com/main/ranking/read.nhn?m...   연합뉴스  130,198
# 3  https://news.naver.com/main/ranking/read.nhn?m...   동아일보  120,897
# 4  https://news.naver.com/main/ranking/read.nhn?m...   조선일보  119,463
#
#                                              content   좋아요 훈훈해요 슬퍼요    화나요  \
# 0       // flash 오류를 우회하기 위한 함수 추가 function _flas...   131   16  17   2605
# 1       // flash 오류를 우회하기 위한 함수 추가 function _flas...  1710   32  13   6058
# 2       // flash 오류를 우회하기 위한 함수 추가 function _flas...  1799   19  13   9120
# 3       // flash 오류를 우회하기 위한 함수 추가 function _flas...  3017   19  16    623
# 4       // flash 오류를 우회하기 위한 함수 추가 function _flas...   374   13  14  11468
#
#   후속기사원해요
# 0     121
# 1      48
# 2      30
# 3      37
# 4      38

# %%
# Content 앞 데이터 전처리
def content_replace(x):
    if type(x) != str:
        return
    x = x.replace('// flash 오류를 우회하기 위한 함수 추가 function _flash_removeCallback() {}', " ")
    x = x.replace('\t'," ")
    return x
df_top_news.content = df_top_news.content.map(content_replace)

# %%
df_top_news.head(5)
# Out:
#                                  title  \
# 0   [단독] 황교안 딸 운영 사이트, 대학 진학 후 왜 문 닫았나
# 1     조국 폭풍페북, 日주장 정면반박…"친일파" 표현은 野 반발
# 2   조국, 연일 對日 '항전' 주문…"겁먹고 쫄지말자…싸워 이겨…
# 3             [김순덕의 도발]복수를 하려면 아일랜드처럼!
# 4  조국, 또 페북에 反日 선전전..."文정부, 서희·이순신 역할…
#
#                                                  url  press    views  \
# 0  https://news.naver.com/main/ranking/read.nhn?m...   경향신문  201,039
# 1  https://news.naver.com/main/ranking/read.nhn?m...  머니투데이  185,396
# 2  https://news.naver.com/main/ranking/read.nhn?m...   연합뉴스  130,198
# 3  https://news.naver.com/main/ranking/read.nhn?m...   동아일보  120,897
# 4  https://news.naver.com/main/ranking/read.nhn?m...   조선일보  119,463
#
#                                              content   좋아요 훈훈해요 슬퍼요    화나요  \
# 0          중 3 때 오빠와 장관상이어 고3 때도 ‘장함모’ 활동으로 자원봉사대...   131   16  17   2605
# 1             [머니투데이 김성휘 ,백지수  기자] [[the300]징용판결 ...  1710   32  13   6058
# 2             "文정부, 서희와 이순신 역할 함께 수행…지레 겁먹지 말아야""...  1799   19  13   9120
# 3             친일잔재를 청산하고 한번도 경험하지 못한 나라로 가는 것이 목적...  3017   19  16    623
# 4          "문재인 정부, 국익 수호 위해 '서희' '이순신' 역할 함께 수행"...   374   13  14  11468
#
#   후속기사원해요
# 0     121
# 1      48
# 2      30
# 3      37
# 4      38

# %% [markdown]
# > 본 데이터 프레임은 예시로, 리액션 데이터를 담지 않았습니다. **과제에는 리액션 데이터가 반드시 담겨져있어야합니다.**

# %% [markdown]
# # 데이터 저장
#
# > 파일 형태로 크롤링한 데이터를 저장

# %%
df_top_news.to_csv("top_news.csv")
